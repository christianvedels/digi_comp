# %% [markdown]
# # Practice Questions — Algorithms
# **Digital Competence Module**
#
# Christian Vedel | Department of Economics, University of Southern Denmark
#
# ---
#
# This notebook contains the two practice exercises from the Algorithms lecture. Work through them in order.
#
# **How to run a cell:** Click on it and press `Shift + Enter` (or click the ▶ button on the left).

# %% [markdown]
# ---
# ## Practice 1: Write an If-Then Classifier
#
# **Scenario:** You work for a municipality. Citizens apply for housing support.
#
# **Rules:**
# - Income below 200,000 DKK → `"Full support"`
# - Income between 200,000 and 350,000 DKK → `"Partial support"`
# - Income above 350,000 DKK → `"No support"`
#
# **Task:** Fill in the blanks (`______`) so the code prints the correct support level for a citizen earning 275,000 DKK.

# %%
income = 275000

if income < ______:
    support = "Full support"
elif income < ______:
    support = "______"
else:
    support = "No support"

print(support)

# %% [markdown]
# **Test your solution:** Once it works for 275,000, try changing `income` to 150,000 and 400,000. Do you get the right answer each time?

# %% [markdown]
# ---
# ## Practice 2: Classify Citizens by Income
#
# Below is a simple income classifier. Run it first to see what it does, then complete the three tasks.

# %%
# Starting code — run this first
income = 320000

if income < 300000:
    category = "Low income"
else:
    category = "High income"

print("Income:", income, "→", category)

# %% [markdown]
# **Task 1:** The threshold of 300,000 DKK is arbitrary. Change it to what *you* think is a reasonable cut-off between low and high income in Denmark. Run the cell and verify the output looks right.
#
# **Task 2:** Add a third category: people earning over 800,000 DKK should be classified as `"Very high income"`. You will need to use `elif`.
#
# **Task 3:** Test your classifier on at least three different incomes: one in each category. Print all three results.

# %%
# Your solution for Tasks 1–3:

income = ______  # Try different values

if income < ______:
    category = "Low income"
elif ______:
    category = "High income"
else:
    category = "Very high income"

print("Income:", income, "→", category)

# %% [markdown]
# **Reflection:** You just wrote a simple rule-based classifier — the same kind of logic that underlies many automated systems (benefit eligibility, credit scoring, content moderation). What are the limitations of choosing thresholds by hand like this?

# %% [markdown]
# ---
# *Digital Competence Module, University of Southern Denmark*
